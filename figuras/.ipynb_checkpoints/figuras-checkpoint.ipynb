# %%
def retangulo(char,linhas,colunas):
    for i in range(0,linhas):
        print((char + ' ')* colunas)
        
def trianguloRetangulo(char,linhas):
    for i in range(0,linhas):
        print((char + ' ') * (i+1))
         
def trianguloEquilatero(char,base):
    if base % 2 != 0:
        n = base // 2
        c = 1
        while n >= 0:
            print ((' ' + ' ') * n + (char + ' ') * c)
            n -= 1
            c += 2
    else:
        n = base - 1
        c = 1
        while n >= 0:
            print ((' ') * n + (char + ' ') * c)
            n -= 1
            c += 1
        
def losangulo(char,diagonal):
    if diagonal % 2 != 0:
        n = diagonal // 2
        v = n
        c = 1
        while n >= -v:
            if n > 0:
                print ((' ' + ' ') * n + (char + ' ') * c)
                n -= 1
                c += 2
            else:
                print ((' ' + ' ') * abs(n) + (char + ' ') * c)
                n -= 1
                c -= 2
    else:
        n = diagonal - 1
        v = n
        c = 1
        while n >= -v:
            if n > 0:
                print ((' ') * n + (char + ' ') * c)
                n -= 1
                c += 1
            else:
                print ((' ') * abs(n) + (char + ' ') * c)
                n -= 1
                c -= 1

# %%
char = '@'
for i in range(2,10):
    retangulo(char,i,i)
    print('\n')
    trianguloRetangulo(char,i)
    print('\n')
    trianguloEquilatero(char,i)
    print('\n')
    losangulo(char,i)
    print('\n')
# Out:
# @ @
# @ @
#
#
# @
# @ @
#
#
#  @
# @ @
#
#
#  @
# @ @
#  @
#
#
# @ @ @
# @ @ @
# @ @ @
#
#
# @
# @ @
# @ @ @
#
#
#   @
# @ @ @
#
#
#   @
# @ @ @
#   @
#
#
# @ @ @ @
# @ @ @ @
# @ @ @ @
# @ @ @ @
#
#
# @
# @ @
# @ @ @
# @ @ @ @
#
#
#    @
#   @ @
#  @ @ @
# @ @ @ @
#
#
#    @
#   @ @
#  @ @ @
# @ @ @ @
#  @ @ @
#   @ @
#    @
#
#
# @ @ @ @ @
# @ @ @ @ @
# @ @ @ @ @
# @ @ @ @ @
# @ @ @ @ @
#
#
# @
# @ @
# @ @ @
# @ @ @ @
# @ @ @ @ @
#
#
#     @
#   @ @ @
# @ @ @ @ @
#
#
#     @
#   @ @ @
# @ @ @ @ @
#   @ @ @
#     @
#
#
# @ @ @ @ @ @
# @ @ @ @ @ @
# @ @ @ @ @ @
# @ @ @ @ @ @
# @ @ @ @ @ @
# @ @ @ @ @ @
#
#
# @
# @ @
# @ @ @
# @ @ @ @
# @ @ @ @ @
# @ @ @ @ @ @
#
#
#      @
#     @ @
#    @ @ @
#   @ @ @ @
#  @ @ @ @ @
# @ @ @ @ @ @
#
#
#      @
#     @ @
